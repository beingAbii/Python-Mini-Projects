# %% [markdown]
# # QUIZ PROGRAM

# %%
quiz = {            # a dictionary that stores question and answer
 "Question 1":{     # Qustion 1 is the key of the dictionary
   "question": "What is the capital of France: ",
   "Answer":"Paris" #question and answer are the values of the key
  },   
 "Question 2":{    
   "question": "What is the capital of Germany: ",
   "Answer":"Berlin"
  },
 "Question 3":{    
   "question": "What is the capital of Italy: ",
   "Answer":"Rome"
  },
 "Question 4":{    
   "question": "What is the capital of Spain: ",
   "Answer":"Madrid"
  },
 "Question 5":{    
   "question": "What is the capital of Portugal: ",
   "Answer":"Lisbon"
  },
 "Question 6":{    
   "question": "What is the capital of Austria: ",
   "Answer":"Vienna"
  },
 "Question 7":{    
   "question": "What is the capital of Switzerland: ",
   "Answer":"Bern"
  },
}

score = 0

for key, value in quiz.items():
    
    print(value['question'])
    answer = input("answer ?")
    
    if answer.lower() == value['Answer'].lower():
        print("correct")
        score = score + 1
        print("Your score is " + str(score) + " out of 7 ")
        print("")
        print("")
    else:
        print("wrong answer!")
        print("The answer is " + value['Answer'])
        print("Your score is " + str(score) + " out of 7" )
        print("")
        print("")
# Out:
# What is the capital of France:
# answer ?PARIS
# correct
# Your score is 1 out of 7
#
#
# What is the capital of Germany:
# answer ?BERLIN
# correct
# Your score is 2 out of 7
#
#
# What is the capital of Italy:
# answer ?ROME
# correct
# Your score is 3 out of 7
#
#
# What is the capital of Spain:
# answer ?MADRID
# correct
# Your score is 4 out of 7
#
#
# What is the capital of Portugal:
# answer ?LISBON
# correct
# Your score is 5 out of 7
#
#
# What is the capital of Austria:
# answer ?VIENNA
# correct
# Your score is 6 out of 7
#
#
# What is the capital of Switzerland:
# answer ?BERN
# correct
# Your score is 7 out of 7
